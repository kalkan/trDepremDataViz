# %% [markdown]
# <a href="https://colab.research.google.com/github/kalkan/trDepremDataViz/blob/master/trDepremDataViz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas

# %%
import geopandas
import pandas as pd
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(10, 10), dpi=100)

eq = geopandas.read_file("./data/tr-40years-depremdata.shp")
tr = geopandas.read_file("./data/gadm36_TUR_0.shp")

#mag str to numeric 
eq['mag_num'] = pd.to_numeric(eq['mag'])

base = tr.plot(ax=ax, color='white', edgecolor='black')
eq.plot(ax=base, marker='o', color='red', edgecolor='b', alpha=0.5, markersize=eq['mag_num'])

ax.set(title='>4 Magnitude Depremler (1970-2020)')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10), dpi=100)
base = tr.plot(ax=ax, color='white', edgecolor='black')
eq[eq['mag_num'] > 5].plot(ax=base, marker='o', color='red', edgecolor='b', alpha=0.5, markersize=eq['mag_num'])

ax.set(title='>5 Magnitude Depremler (1970-2020)')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10), dpi=100)
base = tr.plot(ax=ax, color='white', edgecolor='black')
eq[eq['mag_num'] > 6].plot(ax=base, marker='o', color='red', edgecolor='b', alpha=0.5, markersize=eq['mag_num'])

ax.set(title='>6 Magnitude Depremler (1970-2020)')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10), dpi=100)
base = tr.plot(ax=ax, color='white', edgecolor='black')
eq[eq['mag_num'] > 7].plot(ax=base, marker='o', color='red', edgecolor='b', alpha=0.5, markersize=eq['mag_num'])

ax.set(title='>7 Magnitude Depremler (1970-2020)')
plt.show()
